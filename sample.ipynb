# %%
test = pd.read_csv("/kaggle/input/ai-201-b-mse-2-aiml-a/test.csv")

# %%
test.info()

# %%
sub = pd.read_csv("/kaggle/input/ai-201-b-mse-2-aiml-a/sample_submission.csv")

# %%
test.head()

# %%
sub.info()

# %%
sub.head()

# %%
df_big = pd.concat([sub]*10,ignore_index = True)

# %%
df_fin = df_big.head(4152).copy()

# %%
df_fin["id"] = test["id"].values

# %%
df_fin.to_csv("om.csv",index = False)
